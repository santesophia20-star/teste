# %% [markdown]
# <a href="https://colab.research.google.com/github/santesophia20-star/teste/blob/main/aula_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("Hello Word")
# Out:
# Hello Word
